# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitaK1507/Assignment-3-/blob/main/Colab_ass_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input three numbers
a = 3
b = 1
c = 7

# Finding the greatest number
if a >= b and a >= c:
    print("Greatest number is:", a)
elif b >= a and b >= c:
    print("Greatest number is:", b)
else:
    print("Greatest number is:", c)
# Out:
# Greatest number is: 7
